# %%
import os
os.environ["OPENAI_API_KEY"] = os.getenv("OPENAI_API_KEY")

# %%
from langchain.chat_models import init_chat_model
model = init_chat_model("gpt-4.1")

# %% [markdown]
# ### Single Response

# %%
response = model.invoke("Why do parrots talk?")
print(response.content)
# Out:
# Parrots "talk" because they are *vocal learners*, which means they have the ability to mimic sounds they hear in their environment—including human speech. Here’s why and how this happens:
#
# **1. Social Nature:**
# Parrots are highly social animals. In the wild, they communicate with their flocks using a range of calls and sounds. When kept as pets, humans become their flock, so parrots try to communicate with us in the ways they hear us do—by mimicking our words and phrases.
#
# **2. Brain Ability:**
# Parrots have a well-developed brain region called the *song system*, similar to the areas in humans that control speech. This allows them to imitate complex sounds and patterns.
#
# **3. Enrichment and Attention:**
# Parrots often learn to talk because they realize it gets them attention or treats from humans. When a parrot says a word and gets a positive response, it’s encouraged to do it again.
#
# **4. Not True Language:**
# While parrots can mimic human speech impressively, they generally do not *understand* language the way humans do. They associate words and sounds with actions or objects (e.g., saying “Hello” when someone enters a room), but they’re not constructing sentences with grammar or abstract meanings.
#
# **Summary:**
# Parrots talk because it’s a natural extension of their communication skills, driven by their intelligence, social behavior, and the environment they’re in. Their ability to mimic helps them bond and interact with their flock—whether other parrots or humans.

# %% [markdown]
# ### Streaming Response

# %%
for chunk in model.stream("Why do parrots have colorful feathers?"):
    print(chunk.text, end="", flush=True)
# Out:
# Parrots have colorful feathers primarily for **communication, camouflage, and mate attraction**. Here’s how these factors play a role:
#
# 1. **Mate Attraction (Sexual Selection):**
#    - Bright, vibrant feathers often indicate a healthy and genetically fit individual. Parrots use their plumage to attract mates, with more colorful birds generally being preferred as breeding partners.
#    - Some species even perform courtship displays, showing off their feathers to impress potential mates.
#
# 2. **Communication:**
#    - Parrots are social birds, and their bright colors help them recognize and communicate with each other, whether it’s signaling danger, establishing dominance, or identifying flock members.
#
# 3. **Camouflage:**
#    - Surprisingly, colorful feathers can help parrots blend into their natural environment. Many parrots live in lush, tropical forests where vibrant flowers, fruits, and foliage are common. Their colors help them remain hidden from predators among the leaves, flowers, and fruits.
#
# 4. **Species and Individual Recognition:**
#    - The variety and patterns of colors help parrots recognize individuals and distinguish between different species.
#
# **In summary:**
# The bright feathers of parrots have evolved to serve multiple purposes in their environment, enhancing their chances of survival and reproduction.

# %% [markdown]
# ### System & User Prompts

# %%
from langchain_core.messages import SystemMessage, HumanMessage

messages = [
    SystemMessage("You are an English Teacher"),
    HumanMessage("Give me one grammar tips of the day")
]

response = model.invoke(messages)
print(response.content)
# Out:
# **Grammar Tip of the Day:**
#
# When comparing two things, use the comparative form (**-er** or **more**), and when comparing three or more things, use the superlative form (**-est** or **most**).
#
# **Examples:**
# - My house is **bigger** than yours. (Comparing two houses)
# - My house is the **biggest** on the street. (Comparing all the houses on the street)
#
# Remember: For most one-syllable adjectives, add **-er** or **-est**: *small, smaller, smallest.*
# For longer adjectives, use **more** or **most**: *beautiful, more beautiful, most beautiful.*
