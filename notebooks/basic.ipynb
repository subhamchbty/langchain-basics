# %%
import os
os.environ["OPENAI_API_KEY"] = os.getenv("OPENAI_API_KEY")

# %%
from langchain.chat_models import init_chat_model
model = init_chat_model("gpt-4.1")

# %% [markdown]
# ### Single Response

# %%
response = model.invoke("Why do parrots talk?")
print(response.content)
# Out:
# Parrots "talk" because they have the physical ability and, sometimes, the social motivation to mimic human speech and other sounds. Here’s a deeper explanation:
#
# ### 1. **Vocal Abilities (Physical Reason)**
# Parrots have a specialized voice box called the **syrinx**, as well as a flexible tongue and beak. This makes them excellent mimics, able to reproduce a wide range of sounds, including human speech.
#
# ### 2. **Social Intelligence (Psychological Reason)**
# Parrots are highly social birds in the wild. They live in flocks and use complex vocalizations to communicate with each other. In captivity, their human caretakers become their "flock," so parrots try to communicate and fit in by mimicking human speech or household sounds.
#
# ### 3. **Learning and Play**
# Talking (mimicking sounds) can also be a form of play and mental stimulation for parrots. It entertains them and can sometimes get them attention, treats, or interaction from people.
#
# ...

# %% [markdown]
# ### Streaming Response

# %%
for chunk in model.stream("Why do parrots have colorful feathers?"):
    print(chunk.text, end="", flush=True)

# %% [markdown]
# ### System & User Prompts

# %%
from langchain_core.messages import SystemMessage, HumanMessage

messages = [
    SystemMessage("You are an English Teacher"),
    HumanMessage("Give me one grammar tips of the day")
]

response = model.invoke(messages)
print(response.content)
# Out:
# **Grammar Tip of the Day:**
# Use "fewer" for countable nouns and "less" for uncountable nouns.
#
# **Examples:**
# - There are **fewer** apples in the basket. (apples can be counted)
# - I have **less** water in my glass. (water cannot be counted)
#
# Remember: If you can count it, use "fewer." If you can’t count it, use "less."

# %% [markdown]
# ### Dynamic Promp Template

# %%
from langchain_core.prompts import ChatPromptTemplate

template = ChatPromptTemplate.from_messages([
    ("system", "You are a Competitive Exam Coach like SSC, UPSC, Bank Exams in India. You will understand the doubt from the students and clear their doubt on subject {subject}. Based on the user age ({age}) and level of experience ({experience_level}) in {subject}, try to make them understand the answers. Try to keep the answers short and to the point. Do NOT include any suggestion at the end."),
    ("user", "{doubt}")
])

prompt = template.invoke({
    "subject": "History",
    "age": 20,
    "experience_level": "Intermediate",
    "doubt": "How many times India was invaded during 18th Century?"
})

# %%
response = model.invoke(prompt)
print(response.content)
# Out:
# During the 18th century, India was invaded several times, but the most significant invasions were:
#
# 1. **Nadir Shah’s Invasion (1739):** He was the ruler of Persia (Iran) and invaded Delhi, leading to the plundering of the city.
# 2. **Ahmad Shah Abdali’s Invasions (1748–1767):** The Afghan ruler invaded India multiple times—six major invasions are recorded.
#
# So, the two main invaders were Nadir Shah (once) and Ahmad Shah Abdali (six times), making it **seven major invasions** in total during the 18th century.
